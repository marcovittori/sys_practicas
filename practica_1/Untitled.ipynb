# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 6 * np.pi, 100)
y = np.sin(x)

# %%
plt.plot(x, y)
plt.xlabel('time')
plt.ylabel('amplitude')

# remove numbers from x and y axis
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])
